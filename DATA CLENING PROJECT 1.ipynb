# %% [markdown]
# # Imporing a CSV file

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"C:\Users\bhuva\Downloads\amazon_product.csv")
df
# Out:
#     Unnamed: 0        asin                                      product_title  \
# 0            0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1            1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2            2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3            3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4            4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
# 5            5  B0CSB22F9C  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 6            6  B0CV4NQYFP  SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...
# 7            7  B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 8            8  B0BLZN9NDG  SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...
# 9            9  B0CP6DDN1H  Moto G Play | 2024 | Unlocked | Made for US 4/...
# 10          10  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# ...

# %% [markdown]
# # checking wheather the file is loaded or not

# %%
df.head()
# Out:
#    Unnamed: 0        asin                                      product_title  \
# 0           0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1           1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2           2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3           3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4           4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
#
#   product_price product_original_price currency  product_star_rating  \
# 0       $99.99                $169.99       USD                  4.0
# 1      $149.74                $158.00       USD                  4.2
# 2       $49.88                     NaN      USD                  3.9
# 3      $335.00                $499.00       USD                  4.3
# 4      $199.99                     NaN      USD                  4.1
#
#    product_num_ratings                           product_url  \
# ...

# %% [markdown]
# # Displaying all the rows

# %%
pd.set_option('display.max.rows',None)

# %%
df
# Out:
#     Unnamed: 0        asin                                      product_title  \
# 0            0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1            1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2            2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3            3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4            4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
# 5            5  B0CSB22F9C  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 6            6  B0CV4NQYFP  SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...
# 7            7  B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 8            8  B0BLZN9NDG  SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...
# 9            9  B0CP6DDN1H  Moto G Play | 2024 | Unlocked | Made for US 4/...
# 10          10  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# ...

# %% [markdown]
# # Shape of the Dataset

# %%
df.shape
# Out:
# (64, 22)

# %% [markdown]
# # information of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   64 non-null     int64
#  1   asin                         64 non-null     object
#  2   product_title                64 non-null     object
#  3   product_price                64 non-null     object
#  4   product_original_price       27 non-null     object
#  5   currency                     64 non-null     object
#  6   product_star_rating          54 non-null     float64
#  7   product_num_ratings          64 non-null     int64
#  8   product_url                  64 non-null     object
#  9   product_photo                64 non-null     object
#  10  product_num_offers           64 non-null     int64
#  11  product_minimum_offer_price  64 non-null     object
#  12  is_best_seller               64 non-null     bool
# ...

# %% [markdown]
# # Sum of the NULL values in the Dataset

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# asin                            0
# product_title                   0
# product_price                   0
# product_original_price         37
# currency                        0
# product_star_rating            10
# product_num_ratings             0
# product_url                     0
# product_photo                   0
# product_num_offers              0
# product_minimum_offer_price     0
# is_best_seller                  0
# is_amazon_choice                0
# is_prime                        0
# climate_pledge_friendly         0
# sales_volume                    3
# delivery                        1
# has_variations                  0
# product_availability           63
# unit_price                     59
# unit_count                     59
# dtype: int64

# %% [markdown]
# # Droping the Duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#     Unnamed: 0        asin                                      product_title  \
# 0            0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1            1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2            2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3            3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4            4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
# 5            5  B0CSB22F9C  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 6            6  B0CV4NQYFP  SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...
# 7            7  B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 8            8  B0BLZN9NDG  SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...
# 9            9  B0CP6DDN1H  Moto G Play | 2024 | Unlocked | Made for US 4/...
# 10          10  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# ...

# %% [markdown]
# # Displaying the columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'asin', 'product_title', 'product_price',
#        'product_original_price', 'currency', 'product_star_rating',
#        'product_num_ratings', 'product_url', 'product_photo',
#        'product_num_offers', 'product_minimum_offer_price', 'is_best_seller',
#        'is_amazon_choice', 'is_prime', 'climate_pledge_friendly',
#        'sales_volume', 'delivery', 'has_variations', 'product_availability',
#        'unit_price', 'unit_count'],
#       dtype='object')

# %% [markdown]
# # Finding the NULL values in the particular columns

# %%
df['product_original_price'].isnull().sum()
# Out:
# 37

# %%
df['product_price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Droping the particular columns

# %%
df = df.drop(columns = ['Unnamed: 0', 'asin', 'product_original_price', 'product_url', 'product_photo', 'product_minimum_offer_price', 'is_best_seller','is_amazon_choice', 'is_prime', 'climate_pledge_friendly','has_variations', 'product_availability',
       'unit_price', 'unit_count'])
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...       $99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...      $149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...       $49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...      $335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...      $199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...      $129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...      $349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...       $49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...       $87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...      $129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...       $70.61       USD
# ...

# %% [markdown]
# # Replacing the values

# %%
df['product_price'] = df['product_price'].str.replace('$','')
df['product_price']
# Out:
# 0      99.99
# 1     149.74
# 2      49.88
# 3     335.00
# 4     199.99
# 5     129.99
# 6     349.99
# 7      49.39
# 8      87.10
# 9     129.99
# 10     70.61
# 11     48.75
# 12     99.99
# 13    499.00
# 14    199.99
# 15     38.67
# 16     23.99
# 17     84.99
# 18      0.25
# 19      0.49
# 20      2.39
# 21     18.09
# 22     19.78
# 23      0.00
# 24     55.99
# 25      6.68
# 26     11.53
# 27     36.98
# 28     27.98
# 29     28.79
# 30      0.00
# 31      0.00
# 32     36.98
# 33      0.00
# 34      3.19
# 35     12.99
# 36      0.00
# 37     22.18
# 38    179.99
# 39     19.02
# 40     14.98
# 41     67.28
# 42      0.00
# 43      0.00
# 44      0.00
# 45      0.00
# 46     24.49
# 47     11.99
# 48      0.00
# 49     29.99
# 50     14.99
# 51     22.00
# 52     39.99
# 53     24.98
# 54      5.99
# 55      0.00
# 56      0.00
# 57     15.99
# 58      0.00
# 59     34.98
# 60     14.99
# 61      0.00
# 62     69.99
# 63     59.99
# Name: product_price, dtype: object

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %% [markdown]
# # Replacing the NULL values with ''

# %%
df = df.fillna('')
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['product_price'] = df['product_price'].str.replace('0.00','')
df['product_price']
# Out:
# 0      99.99
# 1     149.74
# 2      49.88
# 3     335.00
# 4     199.99
# 5     129.99
# 6     349.99
# 7      49.39
# 8      87.10
# 9     129.99
# 10     70.61
# 11     48.75
# 12     99.99
# 13    499.00
# 14    199.99
# 15     38.67
# 16     23.99
# 17     84.99
# 18      0.25
# 19      0.49
# 20      2.39
# 21     18.09
# 22     19.78
# 23
# 24     55.99
# 25      6.68
# 26     11.53
# 27     36.98
# 28     27.98
# 29     28.79
# 30
# 31
# 32     36.98
# 33
# 34      3.19
# 35     12.99
# 36
# 37     22.18
# 38    179.99
# 39     19.02
# 40     14.98
# 41     67.28
# 42
# 43
# 44
# 45
# 46     24.49
# 47     11.99
# 48
# 49     29.99
# 50     14.99
# 51     22.00
# 52     39.99
# 53     24.98
# 54      5.99
# 55
# 56
# 57     15.99
# 58
# 59     34.98
# 60     14.99
# 61
# 62     69.99
# 63     59.99
# Name: product_price, dtype: object

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %% [markdown]
# # Using for loop for droping in paricular columns

# %%
for x in df.index:
    if df.loc[x,'product_price'] == ' ':
        df.drop(x,inplace=True)
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
for x in df.index:
    if df.loc[x,'product_star_rating'] == '':
        df.drop(x,inplace=True)
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %% [markdown]
# # Using replace method

# %%
df['delivery'] = df['delivery'].str.replace('','')
df['delivery']
# Out:
# 0                              FREE delivery Tue, Aug 6
# 1     FREE delivery Wed, Aug 7 Only 7 left in stock ...
# 2                              FREE delivery Tue, Aug 6
# 3                               FREE delivery Aug 6 - 8
# 4                              FREE delivery Tue, Aug 6
# 5                              FREE delivery Tue, Aug 6
# 6     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 7     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 8                              FREE delivery Tue, Aug 6
# 9     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 10                             FREE delivery Wed, Aug 7
# 11                             FREE delivery Wed, Aug 7
# 12    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 13    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 14                             FREE delivery Tue, Aug 6
# 15                             FREE delivery Tue, Aug 6
# 16    FREE delivery Tue, Aug 6 on $35 of items shipp...
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
for x in df.index:
    if df.loc[x,'delivery'] == '':
        df.drop(x,inplace=True)
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['delivery'] = df['delivery'].str.replace('Available instantly','')
df['delivery']
# Out:
# 0                              FREE delivery Tue, Aug 6
# 1     FREE delivery Wed, Aug 7 Only 7 left in stock ...
# 2                              FREE delivery Tue, Aug 6
# 3                               FREE delivery Aug 6 - 8
# 4                              FREE delivery Tue, Aug 6
# 5                              FREE delivery Tue, Aug 6
# 6     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 7     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 8                              FREE delivery Tue, Aug 6
# 9     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 10                             FREE delivery Wed, Aug 7
# 11                             FREE delivery Wed, Aug 7
# 12    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 13    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 14                             FREE delivery Tue, Aug 6
# 15                             FREE delivery Tue, Aug 6
# 16    FREE delivery Tue, Aug 6 on $35 of items shipp...
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
 df['delivery'] =  df['delivery'].str.replace('FREE delivery Wed, Aug 7 on $35 of items shipp...','')
 df['delivery']
# Out:
# 0                              FREE delivery Tue, Aug 6
# 1     FREE delivery Wed, Aug 7 Only 7 left in stock ...
# 2                              FREE delivery Tue, Aug 6
# 3                               FREE delivery Aug 6 - 8
# 4                              FREE delivery Tue, Aug 6
# 5                              FREE delivery Tue, Aug 6
# 6     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 7     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 8                              FREE delivery Tue, Aug 6
# 9     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 10                             FREE delivery Wed, Aug 7
# 11                             FREE delivery Wed, Aug 7
# 12    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 13    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 14                             FREE delivery Tue, Aug 6
# 15                             FREE delivery Tue, Aug 6
# 16    FREE delivery Tue, Aug 6 on $35 of items shipp...
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['delivery'] = df['delivery'].str.replace('FREE delivery Wed, Aug 7 on $35 of items shipped by Amazon','')
df['delivery']
# Out:
# 0                              FREE delivery Tue, Aug 6
# 1     FREE delivery Wed, Aug 7 Only 7 left in stock ...
# 2                              FREE delivery Tue, Aug 6
# 3                               FREE delivery Aug 6 - 8
# 4                              FREE delivery Tue, Aug 6
# 5                              FREE delivery Tue, Aug 6
# 6     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 7     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 8                              FREE delivery Tue, Aug 6
# 9     FREE delivery Tue, Aug 6 Or fastest delivery M...
# 10                             FREE delivery Wed, Aug 7
# 11                             FREE delivery Wed, Aug 7
# 12    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 13    FREE delivery Tue, Aug 6 Or fastest delivery M...
# 14                             FREE delivery Tue, Aug 6
# 15                             FREE delivery Tue, Aug 6
# 16    FREE delivery Tue, Aug 6 on $35 of items shipp...
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['sales_volume'] = df['sales_volume'].str.replace('13-Aug-24','')
df['sales_volume']
# Out:
# 0       6K+ bought in past month
# 1       3K+ bought in past month
# 2       2K+ bought in past month
# 3      10K+ bought in past month
# 4       3K+ bought in past month
# 5       3K+ bought in past month
# 6       3K+ bought in past month
# 7      500+ bought in past month
# 8       1K+ bought in past month
# 9       1K+ bought in past month
# 10      2K+ bought in past month
# 11      5K+ bought in past month
# 12     200+ bought in past month
# 13      2K+ bought in past month
# 14      2K+ bought in past month
# 15      3K+ bought in past month
# 16     10K+ bought in past month
# 17     10K+ bought in past month
# 18     30K+ bought in past month
# 19     40K+ bought in past month
# 20     10K+ bought in past month
# 21                        List:
# 24     700+ bought in past month
# 25     40K+ bought in past month
# 26                        List:
# 29    100K+ bought in past month
# 35     10K+ bought in past month
# 37     60K+ bought in past month
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['sales_volume'] =  df['sales_volume'].str.replace('List:','')        
df['sales_volume']
# Out:
# 0       6K+ bought in past month
# 1       3K+ bought in past month
# 2       2K+ bought in past month
# 3      10K+ bought in past month
# 4       3K+ bought in past month
# 5       3K+ bought in past month
# 6       3K+ bought in past month
# 7      500+ bought in past month
# 8       1K+ bought in past month
# 9       1K+ bought in past month
# 10      2K+ bought in past month
# 11      5K+ bought in past month
# 12     200+ bought in past month
# 13      2K+ bought in past month
# 14      2K+ bought in past month
# 15      3K+ bought in past month
# 16     10K+ bought in past month
# 17     10K+ bought in past month
# 18     30K+ bought in past month
# 19     40K+ bought in past month
# 20     10K+ bought in past month
# 21
# 24     700+ bought in past month
# 25     40K+ bought in past month
# 26
# 29    100K+ bought in past month
# 35     10K+ bought in past month
# 37     60K+ bought in past month
# 38     10K+ bought in past month
# 39
# 41                     19-Jul-24
# ...

# %%
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
df['sales_volume'] = df['sales_volume'].str.replace('19-Jul-24','')
df['sales_volume']
# Out:
# 0       6K+ bought in past month
# 1       3K+ bought in past month
# 2       2K+ bought in past month
# 3      10K+ bought in past month
# 4       3K+ bought in past month
# 5       3K+ bought in past month
# 6       3K+ bought in past month
# 7      500+ bought in past month
# 8       1K+ bought in past month
# 9       1K+ bought in past month
# 10      2K+ bought in past month
# 11      5K+ bought in past month
# 12     200+ bought in past month
# 13      2K+ bought in past month
# 14      2K+ bought in past month
# 15      3K+ bought in past month
# 16     10K+ bought in past month
# 17     10K+ bought in past month
# 18     30K+ bought in past month
# 19     40K+ bought in past month
# 20     10K+ bought in past month
# 21
# 24     700+ bought in past month
# 25     40K+ bought in past month
# 26
# 29    100K+ bought in past month
# 35     10K+ bought in past month
# 37     60K+ bought in past month
# 38     10K+ bought in past month
# 39
# 41
# 47      50+ bought in past month
# ...

# %%
df['sales_volume'] = df['sales_volume'].str.replace('Print List Price:','')
df['sales_volume']
# Out:
# 0       6K+ bought in past month
# 1       3K+ bought in past month
# 2       2K+ bought in past month
# 3      10K+ bought in past month
# 4       3K+ bought in past month
# 5       3K+ bought in past month
# 6       3K+ bought in past month
# 7      500+ bought in past month
# 8       1K+ bought in past month
# 9       1K+ bought in past month
# 10      2K+ bought in past month
# 11      5K+ bought in past month
# 12     200+ bought in past month
# 13      2K+ bought in past month
# 14      2K+ bought in past month
# 15      3K+ bought in past month
# 16     10K+ bought in past month
# 17     10K+ bought in past month
# 18     30K+ bought in past month
# 19     40K+ bought in past month
# 20     10K+ bought in past month
# 21
# 24     700+ bought in past month
# 25     40K+ bought in past month
# 26
# 29    100K+ bought in past month
# 35     10K+ bought in past month
# 37     60K+ bought in past month
# 38     10K+ bought in past month
# 39
# 41
# 47      50+ bought in past month
# ...

# %%
df['sales_volume'] = df['sales_volume'].str.replace('Other formats:','')
df['sales_volume']
# Out:
# 0       6K+ bought in past month
# 1       3K+ bought in past month
# 2       2K+ bought in past month
# 3      10K+ bought in past month
# 4       3K+ bought in past month
# 5       3K+ bought in past month
# 6       3K+ bought in past month
# 7      500+ bought in past month
# 8       1K+ bought in past month
# 9       1K+ bought in past month
# 10      2K+ bought in past month
# 11      5K+ bought in past month
# 12     200+ bought in past month
# 13      2K+ bought in past month
# 14      2K+ bought in past month
# 15      3K+ bought in past month
# 16     10K+ bought in past month
# 17     10K+ bought in past month
# 18     30K+ bought in past month
# 19     40K+ bought in past month
# 20     10K+ bought in past month
# 21
# 24     700+ bought in past month
# 25     40K+ bought in past month
# 26
# 29    100K+ bought in past month
# 35     10K+ bought in past month
# 37     60K+ bought in past month
# 38     10K+ bought in past month
# 39
# 41
# 47      50+ bought in past month
# ...

# %%
for x in df.index:
    if df.loc[x,'sales_volume']  == ' ':
        df.drop(x,inplace=True)
df
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %% [markdown]
# # Reseting the index

# %%
df.reset_index(drop=True)
# Out:
#                                         product_title product_price currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        99.99       USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       149.74       USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        49.88       USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       335.00       USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       199.99       USD
# 5   Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...       129.99       USD
# 6   SAMSUNG Galaxy A35 5G A Series Cell Phone, 128...       349.99       USD
# 7   TracFone | Motorola Moto g Pure | Locked | 32G...        49.39       USD
# 8   SAMSUNG,Galaxy A04e (SM-A042M/DS) Dual SIM 32G...        87.10       USD
# 9   Moto G Play | 2024 | Unlocked | Made for US 4/...       129.99       USD
# 10  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...        70.61       USD
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\bhuva

# %% [markdown]
# # Loading the cleaned dataset to csv file

# %%
df.to_csv('Cleaned_amazon_data.csv', inplace=False)
